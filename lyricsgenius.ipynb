# %%
from lyricsgenius import Genius
import os

# %%
api_id = os.environ['GENIUS_ID']
api_key = os.environ['GENIUS_API']
token = 'hPczIRmViDoMyUOeB0qbpURP9IzvtRgnGCT8BcQAqyoKHLmXCL4NVo-XkyjMy7xl'

# %%
genius = Genius(token)
doggystyle = genius.search_album('Doggy Style', 'Snoop Dogg')
# Out:
# Searching for "Doggy Style" by Snoop Dogg...

# %%
doggystyle.save_lyrics()
# Out:
# Wrote Lyrics_Doggystyle.json.

# %%
import pandas as pd
import json
from pprint import pprint

# %%
with open('Lyrics_Doggystyle.json') as f:
    doggystyle = json.load(f)
pprint(doggystyle)
# Out:
# {'_type': 'album',
#  'api_path': '/albums/9337',
#  'artist': {'_type': 'artist',
#             'api_path': '/artists/46',
#             'header_image_url': 'https://images.genius.com/4a8a11f406cfaa80085daaee24b78863.1000x563x1.jpg',
#             'id': 46,
#             'image_url': 'https://images.genius.com/91bd22f5e53a3ea3cb1436de8f4a3722.1000x1000x1.jpg',
#             'index_character': 's',
#             'iq': 5147,
#             'is_meme_verified': True,
#             'is_verified': True,
#             'name': 'Snoop Dogg',
#             'slug': 'Snoop-dogg',
#             'url': 'https://genius.com/artists/Snoop-dogg'},
#  'cover_art_thumbnail_url': 'https://images.genius.com/d31a03639b8f8f4259b9b9da07972d52.300x301x1.jpg',
#  'cover_art_url': 'https://images.genius.com/d31a03639b8f8f4259b9b9da07972d52.996x1000x1.jpg',
#  'full_title': 'Doggystyle by Snoop Dogg',
#  'id': 9337,
#  'name': 'Doggystyle',
#  'name_with_artist': 'Doggystyle (artist: Snoop Dogg)',
# ...

# %%
thediary = genius.search_album('The Diary', 'Scarface')
# Out:
# Searching for "The Diary" by Scarface...
# <bound method Album.save_lyrics of Album(id, artist, ...)>

# %%
thediary.save_lyrics()
# Out:
# Wrote Lyrics_TheDiary.json.

# %%
resurrection = genius.search_album('Resurrection', 'Common')
resurrection.save_lyrics()
# Out:
# Searching for "Resurrection" by Common...
# Wrote Lyrics_Resurrection.json.

# %%
with open('Lyrics_TheDiary.json') as f:
    album = json.load(f)
artist = album['artist']['name']
album_title = album['name']
year = album['release_date_components']['year']
print(artist, album_title, year)
# Out:
# Scarface The Diary 1994

# %%
album.keys()
# Out:
# dict_keys(['_type', 'api_path', 'cover_art_thumbnail_url', 'cover_art_url', 'full_title', 'id', 'name', 'name_with_artist', 'release_date_components', 'release_date_for_display', 'url', 'artist', 'tracks'])

# %%
pprint(album)
# Out:
# {'_type': 'album',
#  'api_path': '/albums/9047',
#  'artist': {'_type': 'artist',
#             'api_path': '/artists/127',
#             'header_image_url': 'https://images.genius.com/9d02cf1e664a767d419d0f9399beae56.1000x473x1.png',
#             'id': 127,
#             'image_url': 'https://images.genius.com/4a83e0fa554b5f2e5c5acce61362bbe7.1000x1000x1.png',
#             'index_character': 's',
#             'iq': 5554,
#             'is_meme_verified': True,
#             'is_verified': True,
#             'name': 'Scarface',
#             'slug': 'Scarface',
#             'url': 'https://genius.com/artists/Scarface'},
#  'cover_art_thumbnail_url': 'https://images.genius.com/18ccee2c198d56c7f1368268755e5bd3.300x290x1.jpg',
#  'cover_art_url': 'https://images.genius.com/18ccee2c198d56c7f1368268755e5bd3.1000x966x1.jpg',
#  'full_title': 'The Diary by Scarface',
#  'id': 9047,
#  'name': 'The Diary',
#  'name_with_artist': 'The Diary (artist: Scarface)',
# ...
